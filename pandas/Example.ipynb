# %%
import numpy as np
import pandas as pd
import bokeh.plotting as bk
bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="defb8261-c934-479f-af98-542c7e021a64">Loading BokehJS ...</span>
#     </div>

# %%
dataFolder = 'temp/baby_names/'
columnNames = ['name', 'sex', 'births']

names1880 = pd.read_csv(dataFolder+'yob1880.txt', names=columnNames)
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %%
years = range(1880, 2012)
parts = []
for year in years:
    path = '{0}yob{1}.txt'.format(dataFolder, year)
    frame = pd.read_csv(path, names=columnNames)
    frame['year'] = year  
    parts.append(frame)

# %%
names = pd.concat(parts, ignore_index=True)
names[::10**5]
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 100000       Ernie   F      13  1912
# 200000     Lemoyne   M       9  1922
# 300000     Derrell   M      43  1932
# 400000   Valentine   M      56  1943
# 500000        Neal   M     968  1953
# 600000       Konni   F      14  1962
# 700000      Howard   F      18  1970
# 800000     Tomecca   F       6  1976
# 900000    Martrell   M       8  1981
# 1000000  Clearence   M       6  1986
# 1100000    Indiana   F      15  1991
# 1200000    Aminata   F      30  1995
# 1300000     Yutaro   M       8  1998
# 1400000         Mc   F      14  2002
# 1500000  Marshayla   F       7  2005
# 1600000    Treonna   F       9  2008
# 1700000    Kellsie   F      13  2011

# %% [markdown]
# ##  Pivoting

# %%
from bokeh.models.ranges import Range1d
totalBirths = names.pivot_table('births', index='year', columns='sex',
                                aggfunc=sum, margins=False)
#display(totalBirths.head())
#totalBirths[['F', 'M']][:-1].plot(title='Total births by sex and year')
fig = bk.figure(plot_width=750, plot_height=300, title=None)
fig.line(x=totalBirths.index, y=totalBirths['F'], legend='F', line_color='magenta')
fig.line(x=totalBirths.index, y=totalBirths['M'], legend='M', line_color='royalblue')
fig.legend.orientation = 'horizontal'
fig.xaxis.axis_label = 'Year'
fig.yaxis.axis_label = 'Total births'
fig.yaxis[0].formatter.use_scientific = False
bk.show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="599dcb22-1484-4fe0-b82f-abf9bd8f41bc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("599dcb22-1484-4fe0-b82f-abf9bd8f41bc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("599dcb22-1484-4fe0-b82f-abf9bd8f41bc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '599dcb22-1484-4fe0-b82f-abf9bd8f41bc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"666cf69e-fc6e-4228-b958-3883797462ca":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"789e20c9-197b-490c-a90e-b5f3d3915170","type":"PanTool"},{"id":"f2757eaf-4690-4c35-ad63-b20a8c968d74","type":"WheelZoomTool"},{"id":"68760575-fbd0-43ea-a19a-48faf943a4c5","type":"BoxZoomTool"},{"id":"12129f10-1087-4770-af55-a27e8d3846d8","type":"SaveTool"},{"id":"ff1a70dc-e3b6-4d24-9beb-870d1e0b508e","type":"ResetTool"},{"id":"31df0356-cc42-4dd4-b930-3b3d7a5700a5","type":"HelpTool"}]},"id":"6e7bb925-c321-4008-b17e-092e74df0960","type":"Toolbar"},{"attributes":{"plot":{"id":"94ae8862-a648-487d-b585-44ffa53e7441","subtype":"Figure","type":"Plot"}},"id":"31df0356-cc42-4dd4-b930-3b3d7a5700a5","type":"HelpTool"},{"attributes":{"line_color":{"value":"royalblue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"948ab234-8b55-4c62-80b4-cb4f784daa02","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011],"y":[110492,100747,113687,104631,114445,107801,110786,101415,120855,110589,111025,101197,122039,112319,115775,117398,119572,112759,122702,106216,150532,106475,122661,119238,128129,132320,133162,146836,154344,163986,194203,225940,429924,512519,654758,848626,890110,925513,1013614,980183,1064486,1101442,1088330,1096161,1132692,1115826,1110482,1126463,1107204,1074975,1096851,1038764,1043594,990849,1032009,1040766,1036781,1066059,1108569,1106394,1158710,1227701,1380576,1426504,1362344,1345611,1623837,1827854,1752974,1771812,1790249,1877969,1943472,1968980,2037085,2057615,2113292,2155583,2120247,2133237,2132719,2121967,2068678,2031605,1992960,1861278,1783751,1744349,1738723,1789616,1859075,1768631,1622358,1558841,1572714,1561702,1569401,1643115,1641481,1721155,1782908,1789955,1813013,1790936,1802998,1846408,1839585,1865251,1912053,1999923,2052205,2019220,1995998,1959889,1930611,1902293,1892859,1883708,1909813,1918448,1961949,1940786,1939273,1972784,1982022,1993948,2051108,2070445,2034014,1976208,1909167,1880633]}},"id":"8581184f-b632-45f5-9f8e-4ca50c36480a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"94ae8862-a648-487d-b585-44ffa53e7441","subtype":"Figure","type":"Plot"}},"id":"12129f10-1087-4770-af55-a27e8d3846d8","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011],"y":[90994,91955,107851,112322,129022,133056,144536,145982,178629,178367,190377,185484,212350,212907,222923,233632,237923,234199,258772,233023,299853,239349,264078,261975,275373,291636,295303,318565,334303,347210,396445,418229,557982,624399,761439,983851,1044283,1081213,1157612,1130157,1198252,1232914,1200839,1206242,1248807,121728 ...

# %% [markdown]
# ## Splitting

# %%
names.groupby(['year', 'sex'])['births'].sum().head()
# Out:
# year  sex
# 1880  F       90994
#       M      110492
# 1881  F       91955
#       M      100747
# 1882  F      107851
# Name: births, dtype: int64

# %%
boys = names[names.sex == 'M']
girls = names[names.sex == 'F']
boys[:2000:100]
# Out:
#           name sex  births  year
# 942       John   M    9655  1880
# 1042     Perry   M     134  1880
# 1142   Clayton   M      60  1880
# 1242    Judson   M      31  1880
# 1342    Wilmer   M      19  1880
# 1442     Rubin   M      14  1880
# 1542     Alois   M      10  1880
# 1642   Fayette   M       8  1880
# 1742     Toney   M       7  1880
# 1842     Titus   M       6  1880
# 1942  Leonidas   M       5  1880
# 2980       Tom   M     349  1881
# 3080    Lester   M      87  1881
# 3180     Elias   M      41  1881
# 3280      Hans   M      23  1881
# 3380    Aubrey   M      15  1881
# 3480      Ford   M      11  1881
# 3580    Rafael   M       9  1881
# 3680     Handy   M       7  1881
# 3780      Orla   M       6  1881

# %%
boys[boys['name']=='Jayden']
# Out:
#            name sex  births  year
# 824344   Jayden   M       7  1977
# 843205   Jayden   M       6  1978
# 899512   Jayden   M       9  1981
# 940021   Jayden   M       6  1983
# 960469   Jayden   M       5  1984
# 977725   Jayden   M      10  1985
# 997266   Jayden   M      14  1986
# 1019074  Jayden   M      11  1987
# 1040265  Jayden   M      16  1988
# 1062845  Jayden   M      22  1989
# 1087121  Jayden   M      25  1990
# 1111407  Jayden   M      38  1991
# 1136484  Jayden   M      45  1992
# 1161561  Jayden   M      77  1993
# 1187019  Jayden   M     159  1994
# 1212851  Jayden   M     239  1995
# 1238981  Jayden   M     294  1996
# 1265586  Jayden   M     387  1997
# 1292859  Jayden   M     620  1998
# 1320950  Jayden   M    1230  1999
# 1350145  Jayden   M    1821  2000
# 1380163  Jayden   M    2833  2001
# 1410493  Jayden   M    3853  2002
# 1441364  Jayden   M    5542  2003
# 1472909  Jayden   M    6920  2004
# 1505279  Jayden   M    8244  2005
# 1538659  Jayden   M    9610  2006
# 1573173  Jayden   M   15206  2007
# 1607962  Jayden   M   17105  2008
# 1642694  Jayden   M   17217  2009
# 1676954  Jayden   M   17101  2010
# 1710637  Jayden   M   16861  2011

# %%
bBirths = boys.pivot_table('births', index='year', columns='name',
                           aggfunc=sum, margins=False)
subset = bBirths[['Ray', 'Elvis', 'Sam', 'John', 'Marvin', 'Bob']]

plots = []
for name in subset.columns:
    fig = bk.figure(plot_height=200, plot_width=700, title=None)
    fig.line(x=np.asarray(subset.index), y=np.asarray(subset[name]),
             line_color='black', legend=name)
    plots.append([fig])
bk.show(bk.gridplot(plots))

# Or directly using Pandas (which uses Matplotlib, not Bokeh): 
#subset.plot(subplots=True, figsize=(12, 10), grid=False,
#            title="Number of births per year")
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a220384c-10b2-45b4-b365-74eeb835fdbb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a220384c-10b2-45b4-b365-74eeb835fdbb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a220384c-10b2-45b4-b365-74eeb835fdbb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a220384c-10b2-45b4-b365-74eeb835fdbb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f414ed0d-64e1-45b7-9211-0844156db403":{"roots":{"references":[{"attributes":{"label":{"value":"Bob"},"renderers":[{"id":"848ff95c-7879-4eb3-a3d6-67fc163744fe","type":"GlyphRenderer"}]},"id":"825fba1f-7de1-43e9-94f8-c02d2c5e3007","type":"LegendItem"},{"attributes":{"below":[{"id":"8a942ba9-e2f0-4055-9618-65bdc3f61fe7","type":"LinearAxis"}],"left":[{"id":"5d817d28-c5d7-4821-9430-55c6d2169131","type":"LinearAxis"}],"plot_height":200,"plot_width":700,"renderers":[{"id":"8a942ba9-e2f0-4055-9618-65bdc3f61fe7","type":"LinearAxis"},{"id":"11ef2569-ff3d-4df5-9b99-e045b741553c","type":"Grid"},{"id":"5d817d28-c5d7-4821-9430-55c6d2169131","type":"LinearAxis"},{"id":"5faa7a6e-d751-416c-bb6d-315785bebaef","type":"Grid"},{"id":"a30debba-160f-4110-90ca-9067a8ed4329","type":"BoxAnnotation"},{"id":"3e3b979b-3f45-43a8-9b64-231e2af41f6a","type":"Legend"},{"id":"f948d0c2-f113-4aff-bcf0-63895bd26203","type":"GlyphRenderer"}],"title":null,"tool_events":{"id":"ea13a2d6-b0c7-4586-9fd7-12e8691585a0","type":"ToolEvents"},"toolbar":{"id":"41bd4e4a-be22-429a-af98-bec067ea8ae9","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"f87221d2-60c3-4678-bed7-ed0541615464","type":"DataRange1d"},"y_range":{"id":"84307644-ee95-4678-a498-5b410a8e44c1","type":"DataRange1d"}},"id":"00bf2a03-6f32-4905-9c08-d5234bf11402","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"4fd284c7-8eac-4452-9cf1-b4bc22c8b075","subtype":"Figure","type":"Plot"}},"id":"1f39e1a8-f00a-416b-9e39-6d89fa43dd93","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"017a0453-3dc5-48e6-844d-6c5d86913b9c","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"82930264-4d1b-45fc-bc0f-f0034808ca82","type":"DataRange1d"},{"attributes":{"plot":{"id":"6d69d722-a647-4d1b-9c36-e0b9036f729f","subtype":"Figure","type":"Plot"}},"id":"ffa27a93-e58f-4bd1-9aca-4d74a759c2bc","type":"PanTool"},{"attributes":{"items":[{"id":"a699a46b-e9be-4060-aa6c-83527c9ef457","type":"LegendItem"}],"plot":{"id":"e72706f2-f92e-4894-9d0c-075b2ceed9b0","subtype":"Figure","type":"Plot"}},"id":"6b12109b-7006-40ec-93d6-98e59a7631c8","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011],"y":{"__ndarray__":"...","dtype":"float64","shape":[132]}}},"id":"27556a8a-b6cb-4da3-9633-dd76e24cf780","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"4ee0f836-eff7-4b65-8d3b-fc5ef11401e4","type":"ToolbarBox"},{"id":"3a1e3793-0670-4716-b986-fd8d73f08ec2","type":"Column"}]},"id":"9e2bab7b-da67-47bb-b6a9-2354efd68ce7","type":"Column"},{"attributes":{"children":[{"id":"00bf2a03-6f32-4905-9c08-d5234bf11402","subtype":"Figure","type":"Plot"}]},"id":"dd95528d-1a16-4f1c-9e4b-9e691242254e","type":"Row"},{"attributes":{"children":[{"id":"11ec314a-2cdb-4b03-9071-e2533acabbef","type":"Row"},{"id":"89028188-68d5-4a8f-8017-549765930dbf","type":"Row"},{"id":"07f828d3-b59a-4ab4-ad21-41208daab416","type":"Row"},{"id":"4786d930-053a-4c71-aafa-3457fd8c1f85","type":"Row"},{"id":"dd95528d-1a16-4f1c-9e4b-9e691242254e","type":"Row"},{"id":"74 ...

# %% [markdown]
# ## groupby

# %%
def add_prop(group):
    births = group['births']
    group['prop'] = births/float(births.sum())
    return group

# %%
names = names.groupby(['year', 'sex']).apply(add_prop)
names.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077642
# 1       Anna   F    2604  1880  0.028617
# 2       Emma   F    2003  1880  0.022012
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %%
np.allclose(names.groupby(['year', 'sex'])['prop'].sum(), 1)
# Out:
# True

# %%
def get_top(group, topNumber):
    return group.sort_values(by='births', ascending=False)[:topNumber]

grouped = names.groupby(['year', 'sex'])
topNames = grouped.apply(get_top, topNumber=10)
topNames[:50]
# Out:
#                     name sex  births  year      prop
# year sex
# 1880 F   0          Mary   F    7065  1880  0.077642
#          1          Anna   F    2604  1880  0.028617
#          2          Emma   F    2003  1880  0.022012
#          3     Elizabeth   F    1939  1880  0.021309
#          4        Minnie   F    1746  1880  0.019188
#          5      Margaret   F    1578  1880  0.017342
#          6           Ida   F    1472  1880  0.016177
#          7         Alice   F    1414  1880  0.015539
#          8        Bertha   F    1320  1880  0.014506
#          9         Sarah   F    1288  1880  0.014155
#      M   942        John   M    9655  1880  0.087382
#          943     William   M    9533  1880  0.086278
#          944       James   M    5927  1880  0.053642
#          945     Charles   M    5348  1880  0.048402
#          946      George   M    5126  1880  0.046392
#          947       Frank   M    3242  1880  0.029341
#          948      Joseph   M    2632  1880  0.023821
#          949      Thomas   M    2534  1880  0.022934
#          950       Henry   M    2444  1880  0.022119
#          951      Robert   M    2415  1880  0.021857
# 1881 F   2000       Mary   F    6919  1881  0.075243
#          2001       Anna   F    2698  1881  0.029340
#          2002       Emma   F    2034  1881  0.022120
#          2003  Elizabeth   F    1852  1881  0.020140
#          2004   Margaret   F    1658  1881  0.018031
#          2005     Minnie   F    1653  1881  0.017976
#          2006        Ida   F    1439  1881  0.015649
#          2007      Annie   F    1326  1881  0.014420
#          2008     Bertha   F    1324  1881  0.014398
#          2009      Alice   F    1308  1881  0.014224
#      M   2938       John   M    8769  1881  0.087040
#          2939    William   M    8524  1881  0.084608
#          2940      James   M    5442  1881  0.054016
#          2941     George   M    4664  1881  0.046294
#          2942    Charles   M    4636  1881  0.046016
#          2943      Frank   M    2834  1881  0.028130
#          2944     Joseph   M    2456  1881  0.024378
#          2945      Henry   M    2339  1881  0.023217
#          2946     Thomas   M    2282  1881  0.022651
#          2947     Edward   M    2177  1881  0.021609
# 1882 F   3935       Mary   F    8149  1882  0.075558
#          3936       Anna   F    3143  1882  0.029142
#          3937       Emma   F    2303  1882  0.021354
#          3938  Elizabeth   F    2187  1882  0.020278
#          3939     Minnie   F    2004  1882  0.018581
#          3940   Margaret   F    1821  1882  0.016884
#          3941        Ida   F    1673  1882  0.015512
#          3942      Alice   F    1542  1882  0.014298
#          3943     Bertha   F    1508  1882  0.013982
#          3944      Annie   F    1492  1882  0.013834

# %%
from bokeh.models.ranges import Range1d

diversity = topNames.pivot_table('prop', index='year', columns='sex', aggfunc=sum)

fig = bk.figure(plot_width=750, plot_height=300, title=None)
fig.line(x=diversity.index, y=diversity['F'], line_color='green', legend='F')
fig.line(x=diversity.index, y=diversity['M'], line_color='blue',  legend='M')
fig.y_range = Range1d(0, 1.2)
bk.show(fig)

# Or, using directly Pandas' "plot" method (which calls Matplotlib, not Bokeh)
# diversity.plot(title='Sum of diversity.prop by year and sex',
#                yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="704db2c4-c985-4530-ba9b-01dab40cd0d7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("704db2c4-c985-4530-ba9b-01dab40cd0d7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("704db2c4-c985-4530-ba9b-01dab40cd0d7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '704db2c4-c985-4530-ba9b-01dab40cd0d7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f26d94db-f215-4fde-b4d8-90d5958a5df1":{"roots":{"references":[{"attributes":{"plot":{"id":"934ab824-f918-4dba-9e15-927dba058a35","subtype":"Figure","type":"Plot"}},"id":"b056a4e2-015e-412a-ae4f-3feaf8f3af0f","type":"ResetTool"},{"attributes":{"plot":{"id":"934ab824-f918-4dba-9e15-927dba058a35","subtype":"Figure","type":"Plot"},"ticker":{"id":"d03f1224-e3ae-48b0-800b-8a788dee9aec","type":"BasicTicker"}},"id":"1fe57403-4f37-40ec-afb8-f1f9ecca8cc0","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011],"y":{"__ndarray__":"...","dtype":"float64","shape":[132]}}},"id":"07bd5ef2-b0b8-4b3a-9900-f70562020e7e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"934ab824-f918-4dba-9e15-927dba058a35","subtype":"Figure","type":"Plot"}},"id":"bcaccb3f-4417-487d-9321-2b57e1d13e67","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"17aadba1-b723-4380-bc5e-567149149b98","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b60c15b-6c73-4c8a-a3ec-6f847a4340b7","type":"Line"},{"attributes":{"label":{"value":"M"},"renderers":[{"id":"46a9dd63-7506-42a6-91f2-ea5f0d2c9b5d","type":"GlyphRenderer"}]},"id":"acdc64ea-4d8d-4ed5-a418-d40b366b290c","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"768cf52f-0cf1-491c-aca0-695a98f4a357","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"002f8875-3f14-4e54-8ef3-1db3480e15b5","type":"PanTool"},{"id":"bcaccb3f-4417-487d-9321-2b57e1d13e67","type":"WheelZoomTool"},{"id":"287bc252-d35d-4d69-8d36-d756a93127a6","type":"BoxZoomTool"},{"id":"6fb705e2-04bf-4d02-bb93-cd9b78b97a07","type":"SaveTool"},{"id":"b056a4e2-015e-412a-ae4f-3feaf8f3af0f","type":"ResetTool"},{"id":"5ef7a423-08f4-4db7-bf0e-c4d60c0a626b","type":"HelpTool"}]},"id":"33506661-dcc9-4887-9682-403822389eea","type":"Toolbar"},{"attributes":{},"id":"fe467003-72c6-44ab-9947-f7330607a016","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae2f1413-ed02-48aa-ae26-e179f6338d65","type":"Line"},{"attributes":{"data_source":{"id":"dce55e32-f0b4-4331-8d93-3973a4e203d1","type":"ColumnDataSource"},"glyph":{"id":"4247da6f-7433-483a-a4ab-64683efe0e5e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9b60c15b-6c73-4c8a-a3ec-6f847a4340b7","type":"Line"},"selection_glyph":null},"id":"4bf4c15e-cd30-4d91-9d55-ee083ebd12e3","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"934ab824-f918-4dba-9e15-927dba058a35","subtype":"Figure","type":"Plot"}},"id":"5ef7a423-08f4-4db7-bf0e-c4d60c0a626b","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,191 ...
